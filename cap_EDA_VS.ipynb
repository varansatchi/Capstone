# %% [markdown]
# # Capstone EDA - Varan Satchi

# %% [markdown]
# __Proposal__: Analyze ~ three million Russian troll tweets

# %% [markdown]
# __Data Source__: https://fivethirtyeight.com/features/why-were-sharing-3-million-russian-troll-tweets/

# %% [markdown]
# __Proposed Methods and Models / Risks / Assumptions / Goals__:
# 1. Basic Idea: Supervised classification of account_type using NLP vectorizer methods and a model pipline
# 2. Advanced Ideas: In an ideal world, I'd like to incorporate some more advanced concepts. At this point, I'm considering some unsupervised learning method - like clustering - or using neural networks
# 3. I'm relying heavily on the previous due dilligence of the researchers at Clemson University and the editors at FiveThirtyEight, as I've taken the data directly from them (as opposed to scraping via Twitter API). I feel this is not a huge risk / assumption, as both parties are extremely sophisticated
# 4. I wonder if imbalanced classes will be an issue moving forward, as the account types are quite disparate in terms of distribution
# 5. The overall goal of this capstone is to gain an understanding of online politics / astroturfing
#     - the specific goal, at this point, is to effectivley classify Russian internet trolls

# %%
import pandas as pd

# %%
# loading in the 13 CSVs
df1 = pd.read_csv('./russian-troll-tweets/IRAhandle_tweets_1.csv')
df2 = pd.read_csv('./russian-troll-tweets/IRAhandle_tweets_2.csv')
df3 = pd.read_csv('./russian-troll-tweets/IRAhandle_tweets_3.csv')
df4 = pd.read_csv('./russian-troll-tweets/IRAhandle_tweets_4.csv')
df5 = pd.read_csv('./russian-troll-tweets/IRAhandle_tweets_5.csv')
df6 = pd.read_csv('./russian-troll-tweets/IRAhandle_tweets_6.csv')
df7 = pd.read_csv('./russian-troll-tweets/IRAhandle_tweets_7.csv')
df8 = pd.read_csv('./russian-troll-tweets/IRAhandle_tweets_8.csv')
df9 = pd.read_csv('./russian-troll-tweets/IRAhandle_tweets_9.csv')
df10 = pd.read_csv('./russian-troll-tweets/IRAhandle_tweets_10.csv')
df11 = pd.read_csv('./russian-troll-tweets/IRAhandle_tweets_11.csv')
df12 = pd.read_csv('./russian-troll-tweets/IRAhandle_tweets_12.csv')
df13 = pd.read_csv('./russian-troll-tweets/IRAhandle_tweets_13.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (0,15,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (10,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1.sample() # seems legit
# Out:
#        external_author_id          author  \
# 69543          2586506586  ALEXHARRITONOV
#
#                                                  content      region language  \
# 69543  Украинские гастроли грузинского подкидыша http...  Azerbaijan  Russian
#
#           publish_date   harvested_date  following  followers  updates  \
# 69543  11/11/2016 3:03  11/11/2016 3:03        136       2208     2121
#
#          ...     account_type retweet  account_category new_june_2018  \
# 69543    ...          Russian       1        NonEnglish             0
#
#        alt_external_id            tweet_id  \
# 69543       2586506586  796911228211830784
#
#                                              article_url  \
# 69543  http://twitter.com/2586506586/statuses/7969112...
#
#                                               tco1_step1 tco2_step1 tco3_step1
# 69543  http://www.postsovet.ru/blog/russia/834356.htm...        NaN        NaN
#
# [1 rows x 21 columns]

# %%
# going to combine these dataframes together for ease of use
frames = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13]

# %%
master = pd.concat(frames)

# %%
master.head()
# Out:
#    external_author_id  author  \
# 0  906000000000000000  10_GOP
# 1  906000000000000000  10_GOP
# 2  906000000000000000  10_GOP
# 3  906000000000000000  10_GOP
# 4  906000000000000000  10_GOP
#
#                                              content   region language  \
# 0  "We have a sitting Democrat US Senator on tria...  Unknown  English
# 1  Marshawn Lynch arrives to game in anti-Trump s...  Unknown  English
# 2  Daughter of fallen Navy Sailor delivers powerf...  Unknown  English
# 3  JUST IN: President Trump dedicates Presidents ...  Unknown  English
# 4  19,000 RESPECTING our National Anthem! #StandF...  Unknown  English
#
#       publish_date   harvested_date  following  followers  updates    ...      \
# 0  10/1/2017 19:58  10/1/2017 19:59       1052       9636      253    ...
# 1  10/1/2017 22:43  10/1/2017 22:43       1054       9637      254    ...
# 2  10/1/2017 22:50  10/1/2017 22:51       1054       9637      255    ...
# 3  10/1/2017 23:52  10/1/2017 23:52       1062       9642      256    ...
# 4   10/1/2017 2:13   10/1/2017 2:13       1050       9645      246    ...
#
#   account_type retweet  account_category new_june_2018     alt_external_id  \
# 0        Right       0        RightTroll             0  905874659358453760
# 1        Right       0        RightTroll             0  905874659358453760
# 2        Right       1        RightTroll             0  905874659358453760
# 3        Right       0        RightTroll             0  905874659358453760
# 4        Right       1        RightTroll             0  905874659358453760
#
#              tweet_id                                        article_url  \
# 0  914580356430536707  http://twitter.com/905874659358453760/statuses...
# 1  914621840496189440  http://twitter.com/905874659358453760/statuses...
# 2  914623490375979008  http://twitter.com/905874659358453760/statuses...
# 3  914639143690555392  http://twitter.com/905874659358453760/statuses...
# 4  914312219952861184  http://twitter.com/905874659358453760/statuses...
#
#                                           tco1_step1 tco2_step1 tco3_step1
# 0  https://twitter.com/10_gop/status/914580356430...        NaN        NaN
# 1  https://twitter.com/damienwoody/status/9145685...        NaN        NaN
# 2  https://twitter.com/10_gop/status/913231923715...        NaN        NaN
# 3  https://twitter.com/10_gop/status/914639143690...        NaN        NaN
# 4  https://twitter.com/realDonaldTrump/status/914...        NaN        NaN
#
# [5 rows x 21 columns]

# %%
master.sample(5)
# Out:
#        external_author_id         author  \
# 179241         1682444790  PEYTONCASHOUT
# 254280         2611151319   SEATTLE_POST
# 211257         2912754262    PIGEONTODAY
# 97224          2570574680       RIAFANRU
# 48088          1655194147  MELANYMELANIN
#
#                                                   content         region  \
# 179241  The NBA's Board of Governors has voted to redu...  United States
# 254280  #LobsangDargey was an American success story. ...  United States
# 211257                       '@mashable Yes, I'm a woman'  United States
# 97224   Иран считает С-300 краеугольным камнем отношен...        Belarus
# 48088   Caption this. #KushnerAtWar https://t.co/pyySM...  United States
#
#        language      publish_date    harvested_date  following  followers  \
# 179241  English   7/12/2017 21:29   7/12/2017 21:30        716        774
# 254280  English  10/24/2015 17:48  10/24/2015 17:49       3705      11443
# 211257  English  11/25/2015 15:50  11/25/2015 15:50      16920      19764
# 97224   Russian   4/21/2016 12:40   4/21/2016 12:40       2929      11196
# 48088   English    4/8/2017 19:05    4/8/2017 19:05        890        954
#
#         updates    ...     account_type retweet  account_category  \
# 179241     5142    ...             Left       1         LeftTroll
# 254280    12944    ...            local       0          NewsFeed
# 211257    10669    ...            Right       0        RightTroll
# 97224     50701    ...          Russian       0        NonEnglish
# 48088      5413    ...             Left       1         LeftTroll
#
#        new_june_2018  alt_external_id            tweet_id  \
# 179241             0       1682444790  885249834734698496
# 254280             0       2611151319  657977088096522240
# 211257             0       2912754262  669543579551817729
# 97224              0       2570574680  723129190103539712
# 48088              0       1655194147  850786625575690240
#
#                                               article_url  \
# 179241  http://twitter.com/1682444790/statuses/8852498...
# 254280  http://twitter.com/Seattle_Post/statuses/65797...
# 211257  http://twitter.com/PigeonToday/statuses/669543...
# 97224   http://twitter.com/riafanru/statuses/723129190...
# 48088   http://twitter.com/1655194147/statuses/8507866...
#
#                                                tco1_step1 tco2_step1  \
# 179241                                                NaN        NaN
# 254280  https://twitter.com/Seattle_Post/status/657977...        NaN
# 211257                                                NaN        NaN
# 97224   http://riafan.ru/518121-iran-schitaet-s-300-kr...        NaN
# 48088   https://twitter.com/Delo_Taylor/status/8507841...        NaN
#
#        tco3_step1
# 179241        NaN
# 254280        NaN
# 211257        NaN
# 97224         NaN
# 48088         NaN
#
# [5 rows x 21 columns]

# %%
master.shape
# Out:
# (2946207, 21)

# %%
master.isnull().sum()[master.isnull().sum() != 0]
'''Unsurprised by this result, considering not every tweet will have a region, link etc. attached'''
# Out:
# content             1
# region           8818
# post_type     1648625
# tco1_step1     845971
# tco2_step1    2235090
# tco3_step1    2931207
# dtype: int64

# %%
# Dealing with non-English tweets, while interesting, is beyond my linguistic capabilities!
mask = master['language'] == 'English'
master = master[mask]

# %%
# just checking!
master[master['language'] != 'English']
# Out:
# Empty DataFrame
# Columns: [external_author_id, author, content, region, language, publish_date, harvested_date, following, followers, updates, post_type, account_type, retweet, account_category, new_june_2018, alt_external_id, tweet_id, article_url, tco1_step1, tco2_step1, tco3_step1]
# Index: []
#
# [0 rows x 21 columns]

# %%
master.shape # still have a massive number of tweets
# Out:
# (2116867, 21)

# %%
# as this is a potential target variable, I want to examine it a bit closer
master.account_type.unique()
# Out:
# array(['Right', 'Koch', 'Italian', 'Russian', 'Left', '?', 'German',
#        'Hashtager', 'Arabic', 'local', 'Commercial', 'French',
#        'ZAPOROSHIA', 'news', 'Ebola ', 'Spanish', 'Portuguese'],
#       dtype=object)

# %%
master.groupby('account_type').nunique()
# Out:
#               external_author_id  author  content  region  language  \
# account_type
# ?                            161     207     6271      12         1
# Arabic                        22      22     1027       7         1
# Commercial                     8       6   112353       2         1
# Ebola                          2       2       65       1         1
# French                         3      10       54       3         1
# German                        79     122     2547       7         1
# Hashtager                    114     112   109761       4         1
# Italian                        6       9     1771       2         1
# Koch                         122     121     8543       3         1
# Left                         231     233   330014       4         1
# Portuguese                     1       1        2       1         1
# Right                        449     630   612134       6         1
# Russian                      627     629    12520      21         1
# Spanish                        2       2       79       2         1
# ZAPOROSHIA                     1       1      172       1         1
# local                         37      38   447035       2         1
# news                          16      16   131727       6         1
#
#               publish_date  harvested_date  following  followers  updates  \
# account_type
# ?                     3207            3276        440        317     1164
# Arabic                 944             942        421        274      944
# Commercial           57827           57494        280        792    54408
# Ebola                   70              70          3          2       69
# French                  67              69         37         24       56
# German                2573            2661        981        964     1664
# Hashtager            47972           49115       7674      10120    26467
# Italian               1464            1504         70        102     1377
# Koch                  2930            2988        127         81      631
# Left                168375          177118      11156      20187    14904
# Portuguese               2               2          1          1        2
# Right               212177          220285      19906      37380    61534
# Russian              15529           15804       1488       3355     6622
# Spanish                 68              70          3         19       79
# ZAPOROSHIA              84              84         10         12      169
# local               349076          349092      15165      23444    59398
# news                104264          106636       4424      10206    46543
#
#                  ...      account_type  retweet  account_category  \
# account_type     ...
# ?                ...                 1        2                 1
# Arabic           ...                 1        2                 1
# Commercial       ...                 1        2                 1
# Ebola            ...                 1        1                 1
# French           ...                 1        2                 1
# German           ...                 1        2                 1
# Hashtager        ...                 1        2                 1
# Italian          ...                 1        2                 1
# Koch             ...                 1        2                 1
# Left             ...                 1        2                 1
# Portuguese       ...                 1        1                 1
# Right            ...                 1        2                 1
# Russian          ...                 1        2                 1
# Spanish          ...                 1        1                 1
# ZAPOROSHIA       ...                 1        2                 1
# local            ...                 1        2                 1
# news             ...                 1        2                 1
#
#               new_june_2018  alt_external_id  tweet_id  article_url  \
# account_type
# ?                         2              208      6945         6945
# Arabic                    2               22      1030         1030
# Commercial                1                8    112580       112580
# Ebola                     1                2        70           70
# French                    1               10        70           70
# German                    2              121      3567         3567
# Hashtager                 2              114    236092       236092
# Italian                   2               10      1799         1799
# Koch                      2              121     10759        10759
# Left                      2              233    422141       422141
# Portuguese                1                1         2            2
# Right                     2              631    703571       703574
# Russian                   2              630     20015        20015
# Spanish                   2                2        79           79
# ZAPOROSHIA                1                1       172          172
# local                     2               37    458009       458012
# news                      2               16    138581       138581
#
#               tco1_step1  tco2_step1  tco3_step1
# account_type
# ?                   2890         539          14
# Arabic               562         119           0
# Commercial         95070        8384           1
# Ebola                  2           0           0
# French                52           2           0
# German              2226        1086           2
# Hashtager          22799         792          45
# Italian             1730         572           3
# Koch                1051         116           3
# Left              217417       43048         498
# Portuguese             1           0           0
# Right             377947       71884        2406
# Russian            10385        3831          30
# Spanish               65           7           0
# ZAPOROSHIA            16           0           0
# local             284484      192047        9150
# news               34754        4658          14
#
# [17 rows x 21 columns]

# %%
master['account_type'].value_counts()
# Out:
# Right         704953
# local         458012
# Left          422141
# Hashtager     236092
# news          138581
# Commercial    112580
# Russian        20015
# Koch           10759
# ?               6945
# German          3567
# Italian         1799
# Arabic          1030
# ZAPOROSHIA       172
# Spanish           79
# French            70
# Ebola             70
# Portuguese         2
# Name: account_type, dtype: int64
